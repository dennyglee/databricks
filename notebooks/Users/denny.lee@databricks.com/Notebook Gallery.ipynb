# %% [markdown]
# # Databricks Notebook Gallery
#
# This gallery contains links to various Databricks notebooks, videos, and blogs; please review the notebook's instructions on any of its dependencies.

# %% [markdown]
# ## Spark + AI Summit EU 2019 Featured Demos
#
# <table style="background-color:#ffffe0" style="border:10px solid black">
# <tr>
#   <td valign="top" align="center" width="33%">
#     <a href="$./References/Featured Demos/Koalas: Simplifying PySpark with Pandas" target="_blank">Koalas: Simplifying PySpark with Pandas</a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Koalas_ Simplifying PySpark with Pandas.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/koalas-simplifying-pyspark-pandas.png" alt="koalas-simplifying-pyspark-pandas" width="300" />
#     <br/>
#   </td>
#   <td valign="top" align="center" width="34%">
#     <a href="https://github.com/dennyglee/delta/blob/master/samples/delta-lake-python-dml.ipynb" target="_blank">Ensuring Consistency with Delta Lake (OSS)</a><br/>
#     <a href="https://github.com/dennyglee/delta/blob/master/samples/delta-lake-python-dml.ipynb" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     </a>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Delta-Lake-OSS.mp4" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-video.png" width="80"/>
#     </a>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-delta.png" width=40/>
#     <br/>
#     <center>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/delta-lake-jupyter.png" width=300 align="center"/>
#     </center>
#   </td>
#   <td valign="top" align="center" width="34%">
#     <a href="$./References/Featured Demos/01-Delta Lake Workshop - Delta Lake Primer" target="_blank">Ensuring Consistency with Delta Lake (DB)</a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/01-Delta Lake Workshop - Delta Lake Primer.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     </a>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Delta-Lake-Databricks.mp4" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-video.png" width="80"/>
#     </a>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-delta.png" width=40/>
#     <br/>
#     <center>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/delta-lake-db-map.png" width=300 align="center"/>
#     </center>
#   </td>
# </table>
#
# <br/>

# %% [markdown]
# ## Introduction to Databricks
#
# The following are short introductory videos (3-5min in length) to showcase different aspects of the Databricks product; these will be updated in the near future.
#
# <table>
# <tr>
#   <td>
#     <a href="https://vimeo.com/130273206" target="_blank">
#       Introduction to Databricks<br/>
#       <img src="https://databricks.com/wp-content/uploads/2016/07/OG_Introducing_Databricks.jpg" width=300/>
#     </a>
#   </td>
#   <td>
#     <a href="https://vimeo.com/137874931" target="_blank">
#       Data Exploration in Databricks<br/>
#       <img src="https://databricks.com/wp-content/uploads/2016/07/OG_Data_Exploration.jpg" width=300/>
#     </a>
#   </td>
#   <td>
#     <a href="https://vimeo.com/156886721" target="_blank">
#       Data Visualizations in Databricks<br/>
#       <img src="https://databricks.com/wp-content/uploads/2016/07/OG_Datavisualizations.jpg" width=300/>
#     </a>
#   </td>
# </tr>
# <tr>
#   <td>
#     <a href="https://vimeo.com/137874931" target="_blank">
#       Data Exploration in Databricks<br/>
#       <img src="https://databricks.com/wp-content/uploads/2016/07/OG_Data_Exploration.jpg" width=300/>
#     </a>
#   </td>
#   <td>
#     <a href="https://vimeo.com/156886720" target="_blank">
#       Collaboration in Databricks<br/>
#       <img src="https://databricks.com/wp-content/uploads/2016/07/OG_Collaboration.jpg" width=300>
#     </a>
#   </td>
#   <td>
#     <a href="https://vimeo.com/156886719" target="_blank">
#       Databricks Cluster Manager and Jobs<br/>
#       <img src="https://databricks.com/wp-content/uploads/2016/07/OG_Cluster_Manager__Jobs.jpg" width=300>
#     </a>
#   </td>
# </tr>
# </table>

# %% [markdown]
# <a href="https://databricks.com/spark/getting-started-with-apache-spark" target="_blank"><img src="https://pages.databricks.com/rs/094-YMS-629/images/Getting-Started-with-Apache-Spark-on-Databricks.png" width="970"/></a>

# %% [markdown]
# ## Quick Start
#
# The following are quick start notebooks showing fundamental concepts with Apache Spark and/or Databricks.
# <table>
# <tbody>
# <tr>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Quick_Start/Quick_Start_Using_Python.html" target="_blank" rel="noopener">
#       Quick Start Python<br/>
#        <img class="aligncenter size-medium wp-image-2348" src="https://dennyglee.files.wordpress.com/2016/05/text-x-python-svg.png?w=120" alt="Text-x-python.svg" width="150"/>
#      </a>
#   </td>
#   <td valign="top" align="center" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Quick_Start/Quick_Start_Using_Scala.html" target="_blank" rel="noopener">
#       Quick Start Scala<br/>
#       <img class="aligncenter size-medium wp-image-2347" src="https://dennyglee.files.wordpress.com/2016/05/scala-icon-4.png?w=120" alt="scala-icon-4" width="150" />
#     </a>
#   </td>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Samples/Data_Exploration/Databricks_Data_Import.html" target="_blank" rel="noopener">
#       Data Import<br/>
#       <img class=" size-full wp-image-2346 aligncenter" src="https://dennyglee.files.wordpress.com/2016/05/default-open-graph.png" alt="default-open-graph" width="200"/>
#     </a>
#   </td>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Samples/Data_Exploration/Data_Exploration_on_Databricks.html" target="_blank" rel="noopener">
#       Data Exploration<br/><img class=" size-medium wp-image-2345 aligncenter" src="https://dennyglee.files.wordpress.com/2016/05/data-exploration.png?w=600" alt="Data-Exploration" width="200" />
#     </a>
#   </td>
# </tr>
# <tr>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/eBook/An_Introduction_to_JSON_Support_in_Spark_SQL.html" target="_blank">
#       JSON Support<br/>
#       <img src="https://dennyglee.files.wordpress.com/2016/05/json.png" alt="json" width="200"/>
#     </a>
#   </td>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/eBook/Generalized_Linear_Models_in_SparkR.html" target="_blank">
#       GLM in SparkR<br/>
#       <img src="https://dennyglee.files.wordpress.com/2016/05/r.png" alt="R" width="200">
#     </a>
#   </td>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/eBook/Introducing_Window_Functions_in_Spark_SQL_Notebook.html" target="_blank">
#     Window Functions<br/>
#     <img src="https://dennyglee.files.wordpress.com/2016/05/windowing-functions.png" alt="windowing-functions" width="200"/>
#     </a>
#   </td>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/eBook/Random_Forests_and_Boosting_in_MLlib.html" target="_blank">
#       Random Forests<br/>
#       <img src="https://dennyglee.files.wordpress.com/2016/05/random-boosted-trees.png" alt="random-boosted-trees" width="200"/>
#     </a>
#   </td>
# </tr>
# <tr>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/eBook/Spark_1.5_DataFrame_API_Highlights.html" target="_blank" rel="noopener">
#       DataFrame API<br/>
#       <img class=" size-full wp-image-2326 aligncenter" src="https://dennyglee.files.wordpress.com/2016/05/dataframe-api.png" alt="DataFrame-API" width="200" />
#     </a>
#   </td>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/eBook/ML_Import_Export_and_Simple_Operations.html" target="_blank" rel="noopener">
#       ML Operations <br/>
#       <img class="aligncenter size-medium wp-image-2327" src="https://dennyglee.files.wordpress.com/2016/05/ml-ops.png?w=600" alt="ML-Ops" width="200" />
#     </a>
#   </td>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/eBook/Scalable_Decision_Trees_with_MLlib.html" target="_blank" rel="noopener">
#       Decision Trees<br/>
#       <img class=" size-full wp-image-2328 aligncenter" src="https://dennyglee.files.wordpress.com/2016/05/scalable-dt.png" alt="scalable-DT" width="200" />
#     </a>
#   </td>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/eBook/Scalable_Decision_Trees_with_MLlib.html" target="_blank" rel="noopener">
#       Statistical Functions<br/>
#       <img class=" size-medium wp-image-2329 aligncenter" src="https://dennyglee.files.wordpress.com/2016/05/stats-functions-df.png?w=600" alt="Stats-Functions-DF" width="200" />
#     </a>
#   </td>
# </tr>
# <tr>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Pop._vs._Price_LR.html" target="_blank" rel="noopener">
#       Pop vs. Price LR<br/>
#       <img class=" size-full wp-image-2369 aligncenter" src="https://dennyglee.files.wordpress.com/2016/05/pop-price-lr.png" alt="pop-price-LR" width="200"/>
#     </a>
#   </td>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Pop._vs._Price_Multi-Chart.html" target="_blank" rel="noopener">
#       Pop vs. Price DF<br/>
#       <img class=" size-large wp-image-2371 aligncenter" src="https://dennyglee.files.wordpress.com/2016/05/pop-price-sql.png?w=2048" alt="pop-price-SQL" width="200"/>
#     </a>
#   </td>
#   <td valign="top" width="25%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Spark_1.6_Improvements_Multi-Notebook.html" target="_blank">
#       Spark 1.6 (Multiple)<br/>
#       <img class="size-medium wp-image-2395 aligncenter" src="https://dennyglee.files.wordpress.com/2015/05/spark-1-6-multi.png?w=300" alt="Spark-1.6-Multi" width="200"/>
#     </a>
#   </td>
#   <td>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Streaming%20Meetup%20RSVPs.dbc" target="_blank">
#       Streaming Meetup RSVPs<br/>
#       <img class="size-medium wp-image-2395 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/meetup-streaming-small.gif" alt="Streaming-Meetup-RSVPs" width="200"/>
#     </a>
#   </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Highlighted Videos and Presentations
#
# <table style="background-color:#ffffe0" style="border:10px solid black">
# <tr>
#   <td style="border:10px solid black">
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/db-connect-vscode.mp4" target="_blank">
#       Databricks Connect: VSCode<br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-video.png" width=80 />
#       <br/><br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/db-connect-vscode.png" width=300/>
#     </a>
#   </td>
#   <td>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/mnist-keras-hvd-mlflow.mp4" target="_blank">
#       HorovodRunner, Keras, and MLflow<br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-video.png" width=80 />
#       <br/><br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/hvd-diff_opt.gif" width=300/>
#     </a>
#   </td>
#   <td>
#     <a href="https://github.com/dennyglee/databricks/blob/master/presentations/Jump%20Start%20into%20Apache%20Spark%202.0.pdf" target="_blank">
#       Jump Start into Apache Spark 2.0<br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-slides.png" width=80 />
#       <br/><br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/spark-tech-cat.png" width=300/>
#     </a>
#   </td>
# </tr>
# </table>

# %% [markdown]
# ## Deep Learning and MLflow
#
# The following notebooks focus on Deep Learning and MLflow
# <table cellpadding=10 cellspacing=10 border=0>
# <tbody>
# <tr>
#   <td valign="top" width="33%" align="center">
#     <a href="$./References/DLFS/Introduction to Neural Networks, MLflow, and SHAP" target="_blank">Introduction to Neural Networks, MLflow, and SHAP</a>
#     <br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Introduction%20to%20Neural%20Networks%2C%20MLflow%2C%20and%20SHAP.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     </a>
#     <a href="https://www.slideshare.net/databricks/introduction-to-neural-networks-122033415" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-slides.png" width=80/>
#     </a>
#     <a href="https://vimeo.com/292246874/3dafe96108" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-webinar.png" width=80/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://dennyglee.files.wordpress.com/2018/09/nine.png" alt="Introduction to Neural Networks" width="300" />
#     <br/>&nbsp;
#   </td>
#   <td valign="top" width="34%">
#     <a href="$./References/DLFS/Keras MNIST CNN (Part 2)" target="_blank">Training your Neural Network</a>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Keras MNIST CNN %28Part 2%29.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://www.slideshare.net/databricks/training-neural-networks-122043775" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-slides.png" width=80/>
#     </a>
#     <a href="https://vimeo.com/294245579" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-webinar.png" width=80/>
#     <br/><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Keras MNIST CNN %28Part 2%29.html" target="_blank" rel="noopener">
#       <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/diff-optimizers.png" alt="Training your Neural Network" width="300" />
#     </a>
#   </td>
#   <td valign="top" width="33%">
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Keras MNIST CNN %28Part 3%29.html" target="_blank" rel="noopener">
#       <span style="font-size:14pt">Applying your Convolutional Neural Network</span><br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://www.slideshare.net/databricks/applying-your-convolutional-neural-networks" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-slides.png" width=80/>
#     </a>
#     <a href="https://vimeo.com/298433545/75eed5be48" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-webinar.png" width=80/>
#     <br/><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Keras MNIST CNN %28Part 3%29.html" target="_blank" rel="noopener">
#       <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/cnn-arch-small.png" alt="Applying your Convolutional Neural Network" width="300" />
#     </a>
#   </td>
# </tr>
# <tr>
#   <td valign="top" width="33%" align="center">
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/pyData_Seattle_2017-A-Quick-Primer-on-TensorFrames.dbc" target="_blank">
#       TensorFrames and TensorFlow Primer<br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     </a>
#     <a href="https://www.youtube.com/watch?v=qW7fvdW6rGA" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-webinar.png" width=80/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/pyData Seattle 2017 - A Quick Primer on TensorFrames.png" alt="A Quick Primer on TensorFrames" width="300" />
#     <br/><br/>
#   </td>
#   <td valign="top" width="34%">
#     <a href="$./References/MLflow/MLflow Quick Start Notebook (Databricks Hosted Tracking Server)" target="_blank">MLflow Quick Start</a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/MLflow Quick Start Notebook.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://docs.databricks.com/_static/images/mlflow/mlflow-ui.gif" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-video.png" width=80/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://docs.databricks.com/_static/images/mlflow/mlflow-ui.gif" alt="MLflow Quick Start" width="300" />
#   </td>
#   <td valign="top" width="33%">
#     <a href="$./References/MLflow/MLflow-PyTorch" target="_blank">MLflow, PyTorch, and TensorBoard</a><br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     <a href="https://docs.databricks.com/_static/images/mlflow/mlflow-pytorch-tensorboard.gif" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-video.png" width=80/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://docs.databricks.com/_static/images/mlflow/mlflow-pytorch-tensorboard.gif" alt="MLflow, PyTorch, and TensorBoard" width="300" />
#   </td>
# </tr>
# <tr>
#   <td valign="top" width="33%" align="center">
#     <a href="$./References/MLflow/Use MLflow to Experiment a Keras Binary Classification Model for Movie Reviews/Train" target="_blank">MLflow + Keras Movie Review Predictions</a>
#     <br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Use MLflow to Experiment a Keras Binary Classification Model for Movie Reviews.dbc" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     </a>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/keras-mlflow-predict-movie-reviews.png" alt="MLflow + Keras for Movie Review Predictions" width="300" />
#     <br/><br/>
#   </td>
#   <td valign="top" width="34%">
#     <a href="$./References/MLflow/keras-hvdrunner-mlflow-mnist-sample" target="_blank">MNIST with Keras, HorovodRunner, and MLflow</a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/keras-hvdrunner-mlflow-mnist-sample.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/mnist-keras-hvd-mlflow.mp4" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-video.png" width=80/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/hvd-intro.gif" alt="MLflow Quick Start" width="300" />
#   </td>
#   <td valign="top" width="33%">
#     <a href="$./References/MLflow/keras-hvdrunner-mlflow-mnist-experiments" target="_blank">MNIST Experiments with HorovodRunner</a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/keras-hvdrunner-mlflow-mnist-experiments.html" target="_blank">
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/hvd-diff_opt.gif" alt="MNIST Experiments" width="300" />
#   </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## AutoML and Hyperopt
#
# The following notebooks focus on AutoML and Hyperopt
# <table cellpadding=10 cellspacing=10 border=0>
# <tbody>
# <tr>
#   <td valign="top" width="50%" align="center">
#     <a href="$./References/AutoML/automl-simplify-loan-risk-analysis-xgb-optimize" target="_blank">AutoML Toolkit: Auto Optmize XGBoost</a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/automl-simplify-loan-risk-analysis-xgb-optimize.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     </a>
#     <a href="https://databricks.com/blog/2019/09/10/using-automl-toolkit-to-automate-loan-default-predictions.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width=80/>
#     </a>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://databricks.com/wp-content/uploads/2019/09/ML-Pipeline-AutoML-Automation-Runner.png" width="450" />
#     <br/>&nbsp;
#   </td>
#   <td valign="top" width="50">
#     <a href="$./References/AutoML/automl-family-runner-simplify-loan-risk-analysis-sample" target="_blank">AutoML Toolkit: FamilyRunner</a><br/>
#     <a href="$./References/AutoML/automl-family-runner-simplify-loan-risk-analysis-sample" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://databricks.com/wp-content/uploads/2019/09/AutoML-Toolkit-Databricks.png" width="450" />
#   </td>
# </tr>
# <tr>
#   <td valign="top" width="50%">
#     <a href="$./References/AutoML/Distributed Hyperopt + Automated MLflow Tracking" target="_blank">Distributed Hyperopt</a><br/>
#     <a href="https://docs.databricks.com/_static/notebooks/hyperopt-spark-mlflow.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://vimeo.com/343537318" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-webinar.png" width=80/>
#     </a>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/hyperopt-spark-trials-plot.png"  width="450" />
#   </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Object Detection
#
# The following notebooks focus on Object Detection
# <table cellpadding=10 cellspacing=10 border=0>
# <tbody>
# <tr>
#   <td valign="top" width="50%" align="center">
#     <a href="$./References/Object Detection/Object Detection/1. Single Image Extraction" target="_blank">Image Detection</a><br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/five_drinks.jpg" width="450" />
#     <br/>&nbsp;
#   </td>
#   <td valign="top" width="50%">
#     <a href="$./References/Object Detection/Object Detection/2. Multiple Image Extraction" target="_blank">Multiple Image Detection</a><br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/Three-repeated-ImageAI-runs.png" width="450" />
#   </td>
# </tr>
# <tr>
#   <td valign="top" width="50%">
#     <a href="$./References/Object Detection/Object Detection/3. Single Video Extraction" target="_blank">Video Detection</a><br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/object-detection-video.png" width="450" />
#     <br/> &nbsp;
#   </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Change Data Capture with Databricks Delta
#
# <a href="https://databricks.com/blog/2018/10/29/simplifying-change-data-capture-with-databricks-delta.html" target="_blank" rel="noopener">
#   <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
# </a>
# <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-delta.png" width=40/>
# <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-dw.png" width=40/>
# <br/>
#
# <a href="https://databricks.com/blog/2018/10/29/simplifying-change-data-capture-with-databricks-delta.html" target="_blank" rel="noopener">
#   <img class=" size-full wp-image-2358 aligncenter" src="https://databricks.com/wp-content/uploads/2018/10/CDC-Delta-02-v2.gif" alt="mobile-event-stream" width=1000/>
# </a>

# %% [markdown]
# ## Focusing on R
#
# <table>
# <tr>
#   <td valign="top" width="50%" align="center">
#     <a href="https://docs.databricks.com/_static/notebooks/knn-regression-rstudio-databricks.html" target="_blank" rel="noopener">
#       KNN Regression RStudio + Databricks<br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     </a>
#     <a href="https://databricks.com/blog/2018/06/27/rstudio-integration.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width=80/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-r.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <br/>
#     <a href="https://docs.databricks.com/_static/notebooks/knn-regression-rstudio-databricks.html" target="_blank" rel="noopener">
#       <img class=" size-full wp-image-2358 aligncenter" src="https://databricks.com/wp-content/uploads/2018/06/R-min-surface-1024x765.png" alt="ad-tech" width="450" />
#     </a>
#     <br/>
#   </td>
#   <td valign="top" width="50%">
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Survival%20Analysis%20with%20SparkR.html" target="_blank" rel="noopener">
#       <span style="font-size:14pt">Survival Analysis with SparkR</span><br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/></a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-r.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Survival%20Analysis%20with%20SparkR.html" target="_blank" rel="noopener">
#       <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/survival-analysis-with-sparkr.png" alt="ad-tech" width="300" />
#     </a>
#   </td>
# </tr>
# </table>

# %% [markdown]
# ## How Apache Spark performs a fast count using Parquet Metadata
#
# <a href="https://github.com/dennyglee/databricks/blob/master/misc/parquet-count-metadata-explanation.md#how-apache-spark-performs-a-fast-count-using-the-parquet-metadata" target="_blank" rel="noopener">
#   <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
# </a>
# <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
# <br/>
#
# <a href="https://github.com/dennyglee/databricks/blob/master/misc/parquet-count-metadata-explanation.md#how-apache-spark-performs-a-fast-count-using-the-parquet-metadata" target="_blank" rel="noopener">
#   <img class=" size-full wp-image-2358 aligncenter" src="https://github.com/dennyglee/databricks/raw/master/images/Catalyst-Optimizer.png" alt="mobile-event-stream" width=1000/>
# </a>

# %% [markdown]
# ## Horizontal Use Cases
# <table style="background-color:#ffffe0" style="border:10px solid black">
# <tr>
#   <td valign="top" width="33%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Salesforce_Leads_with_Machine_Learning_Spark_SQL_and_UDFs.html" target="_blank" rel="noopener">
#       <span style="font-size:14pt">Salesforce Leads</span><br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-ads.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-viz.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-udf.png" width=40/>
#     <br/>
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Salesforce_Leads_with_Machine_Learning_Spark_SQL_and_UDFs.html" target="_blank" rel="noopener">
#       <img class=" size-medium wp-image-2372 aligncenter" src="https://dennyglee.files.wordpress.com/2016/05/salesforce-leads.png?w=600" alt="salesforce-leads" width="300"/>
#     </a>
#   </td>
#   <td valign="top" align="center">
#     <a href="$./References/Horizontal/Identifying Suspicious Behavior in Video/Video Identification of Suspicious Behavior" target="_blank">Identify Suspicious Video</a><br/>
#     <a href="https://s3.us-east-2.amazonaws.com/databricks-dennylee/notebooks/Identifying+Suspicious+Behavior+in+Video.dbc" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://databricks.com/blog/2018/09/13/identify-suspicious-behavior-in-video-with-databricks-runtime-for-machine-learning.html" target="_blank" rel="noopener">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-video.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-dl.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://databricks.com/wp-content/uploads/2018/09/Browse2.gif" alt="mobile-event-stream" width="300" />
#     <br/>
#   </td>
#   <td valign="top" align="center">
#     <a href="$./References/Horizontal/On-Time Flight Performance" target="_blank">Flight Performance</a><br/>
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Samples/Miscellaneous/On-Time_Flight_Performance.html" target="_blank" rel="noopener">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://databricks.com/blog/2016/03/16/on-time-flight-performance-with-graphframes-for-apache-spark.html" target="_blank" rel="noopener">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-travel.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-gf.png" width=40/>
#     <br/><br/>
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Samples/Miscellaneous/On-Time_Flight_Performance.html" target="_blank" rel="noopener">
#       <img class=" size-full wp-image-2358 aligncenter" src="https://dennyglee.files.wordpress.com/2016/05/flight-perf.png" alt="mobile-event-stream" width="300" />
#     </a>
#     <br/>
#   </td>
# </tr>
# </table>

# %% [markdown]
# ## Ad-Tech
#
# <table style="background-color:#ffffe0" style="border:10px solid black">
# <tr>
#   <td valign="top" width="33%" align="center">
#     <a href="$./References/AdTech/advertising-analytics-click-prediction/advertising-analytics-click-prediction-ml-gbt" target="_blank">Advertising Analytics Click Prediction</a>
#     <br/>
#     <a href="https://s3.us-east-2.amazonaws.com/databricks-dennylee/notebooks/advertising-analytics-click-prediction.dbc" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     </a>
#     <a href="https://databricks.com/blog/2018/07/19/simplify-advertising-analytics-click-prediction-with-databricks-unified-analytics-platform.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width=80/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-ads.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-viz.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-gbt.png" width=40/>
#     <br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/click-v-no-click.png" alt="ad-tech" width="300" />
#     <br/>
#   </td>
#   <td valign="top" width="34%">
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Samples/Miscellaneous/AdTech_Sample_Notebook_Part_1.html" target="_blank" rel="noopener">
#       <span style="font-size:14pt">Ad-Tech Sample Notebook</span><br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/></a>
#     <a href="https://databricks.com/blog/2016/02/02/an-illustrated-guide-to-advertising-analytics.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-ads.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-viz.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-udf.png" width=40/>
#     <br/>
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Samples/Miscellaneous/AdTech_Sample_Notebook_Part_1.html" target="_blank" rel="noopener">
#       <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/os-family.png" alt="ad-tech" width="300" />
#     </a>
#   </td>
# <td valign="top" align="center">
#     <a href="$./References/AdTech/attributionDeltaBlog" target="_blank">Real-Time Attribution</a><br/>
#     <a href="https://s3.us-east-2.amazonaws.com/databricks-dennylee/notebooks/attribution-delta-blog.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://databricks.com/blog/2018/08/09/building-a-real-time-attribution-pipeline-with-databricks-delta.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-ads.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-rt.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-delta.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/real-time-attrib-pipeline.png" alt="stock-data-analysis-streaming-ui" width="300" />
#     <br/>
#   </td>
# </tr>
# </table>

# %% [markdown]
# ## Financial Services
# <table style="background-color:#ffffe0" style="border:10px solid black">
# <tr>
#   <td valign="top" align="center">
#     <a href="$./References/Financial/Loan Risk Analysis" target="_blank">Loan Risk Analysis</a>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/loan-risk-analysis.zip" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://databricks.com/blog/2018/08/09/loan-risk-analysis-with-xgboost-and-databricks-runtime-for-machine-learning.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-finance.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-xgb.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://databricks.com/wp-content/uploads/2018/08/image5-1.png" alt="genome" width="300" />
#     <br/>
#   </td>
#   <td valign="top" align="center">
#     <a href="$./References/Financial/Financial Fraud Detection using Decision Tree Machine Learning Models" target="_blank">Financial Fraud Detection</a>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/financial-fraud-detection-decision-tree.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-finance.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/financial-fraud-detection-confusion-matrix.png" alt="genome" width="300" />
#     <br/>
#   </td>
#   <td valign="top" align="center">
#     <a href="https://databricks.com/blog/2018/07/19/simplify-streaming-stock-data-analysis-using-databricks-delta.html" target="_blank" rel="noopener">
#       <span style="font-size:14pt;">Streaming Stock Analysis</span><br/>
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-finance.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-delta.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-dw.png" width=40/>
#     <br/><br/>
#     <a href="https://databricks.com/blog/2018/07/19/simplify-streaming-stock-data-analysis-using-databricks-delta.html" target="_blank" rel="noopener">
#       <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/stock-data-analysis-streaming-ui.png" alt="stock-data-analysis-streaming-ui" width="300" />
#     </a>
#     <br/>
#   </td>
# </tr>
# </table>

# %% [markdown]
# ## Healthcare and Life Sciences
#
# <table style="background-color:#ffffe0" style="border:10px solid black">
# <tr>
#   <td style="border:10px solid black">
#     <a href="$./References/HLS/engineering_population_scale_gwas" target="_blank">Population Scale GWAS</a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/engineering_population_scale_gwas.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     <a>
#     <a href="https://databricks.com/blog/2019/09/20/engineering-population-scale-genome-wide-association-studies-with-apache-spark-delta-lake-and-mlflow.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width=80 />
#     <a>
#     <br/><br/>
#     <img src="https://databricks.com/wp-content/uploads/2019/09/dashboard-partial.png" width=300/>
#   </td>
#   <td>
#     <a href="$./References/HLS/Simplifying Genomics Pipelines at Scale with Databricks" target="_blank">Simplifying Genomics Pipelines at Scale</a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Simplifying%20Genomics%20Pipelines%20at%20Scale%20with%20Databricks.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width=80 />
#     </a>
#     <a href="https://databricks.com/blog/2019/03/07/simplifying-genomics-pipelines-at-scale-with-databricks-delta.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width=80/>
#     </a>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://databricks.com/wp-content/uploads/2019/03/single_sampleid_amino_acid_map.png" alt="ad-tech" width="350" />
#     <br/>
#   </td>
#   <td valign="top" align="center">
#     <a href="$./References/HLS/Genome Variant Analysis using k-means, ADAM, and Apache Spark" target="_blank">Genome Variant Analysis</a><br/>
#     <a href="http://cdn2.hubspot.net/hubfs/438089/notebooks/Samples/Miscellaneous/Genome_Variant_Analysis_using_k-means_ADAM_and_Apache_Spark.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/></a>
#     <a href="https://databricks.com/blog/2016/05/24/genome-sequencing-in-a-nutshell.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/lightning-viz.gif" alt="genome" width="300" />
#     <br/>
#   </td>
# </tr>
# </table>

# %% [markdown]
# ## Industrial and Manufacturing
#
# <table style="background-color:#ffffe0" style="border:10px solid black">
# <tr>
#   <td valign="top" align="center">
#     <a href="$./References/Industrial/predicting-compressor-failures-using-streaming-k-means" target="_blank">Predicting Compressor Failures</a><br/>
#     <a href="https://s3.us-east-2.amazonaws.com/databricks-dennylee/notebooks/predicting-compressor-failures-using-streaming-k-means.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/></a>
#     <a href="https://databricks.com/blog/2018/07/19/make-your-oil-and-gas-assets-smarter-by-implementing-predictive-maintenance-with-databricks.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-oilgas.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-rt.png" width=40/>
#     <br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/healthy-vs-damaged-compressors.png" alt="ad-tech" width="300" />
#     <br/>
#   </td>
#   <td valign="top" align="center">
#     <a href="$./References/Industrial/Wind Turbine Random Forest - save model, stream" target="_blank">Wind Turbine Predictive Maintenance</a><br/>
#     <a href="$./References/Industrial/Wind Turbine Random Forest - save model, stream" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-oilgas.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-rt.png" width=40/>
#     <br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://s3-us-west-2.amazonaws.com/databricks-demo-images/wind_turbine/wind_small.png" alt="ad-tech" width="300" />
#     <br/>
#   </td>
# </tr>
# </table>

# %% [markdown]
# ## Media & Entertainment
#
# <table style="background-color:#ffffe0" style="border:10px solid black">
# <tr>
#   <td valign="top" align="center">
#     <a href="$./References/Media/mobile-event-stream-etl" target="_blank">Mobile Gaming Streaming</a><br/>
#     <a href="https://docs.databricks.com/_static/notebooks/mobile-event-stream-etl.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://databricks.com/blog/2018/07/02/build-a-mobile-gaming-events-data-pipeline-with-databricks-delta.html" target="_blank" rel="noopener">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-gaming.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-delta.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-rt.png" width=40/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://databricks.com/wp-content/uploads/2018/07/image9.png" alt="mobile-event-stream" width="300" />
#     <br/>
#   </td>
#   <td valign="top" align="center">
#     <a href="$./References/Media/Movies Recommendation Engine XGBoost" target="_blank">Movie Recommendation Engine</a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/Movies Recommendation Engine XGBoost.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-xgb.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/movie-recommendations-xgb.png" alt="genome" width="300" />
#     <br/>
#   </td>
#     <td valign="top" align="center">
#     <a href="$./References/Media/european_soccer_events/european_soccer_events_03_ml" target="_blank">Sports Analysis</a><br/>
#     <a href="https://docs.databricks.com/_static/notebooks/european-soccer-events.dbc" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://databricks.com/blog/2018/07/09/analyze-games-from-european-soccer-leagues-with-apache-spark-and-databricks.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-sports.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <br/><br/>
#       <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/sports-analysis.png" alt="stock-data-analysis-streaming-ui" width="300" />
#     <br/>
#   </td>
# </tr>
# </table>

# %% [markdown]
# ## Retail
#
# <table style="background-color:#ffffe0" style="border:10px solid black">
# <tr>
#   <td valign="top" align="center">
#     <a href="$./References/Retail/Market Basket Analysis using Instacart Online Grocery Dataset" target="_blank">Market Basket Analysis using FP-growth</a><br/>
#     <a href="https://s3.us-east-2.amazonaws.com/databricks-dennylee/notebooks/Market+Basket+Analysis+using+Instacart+Online+Grocery+Dataset.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://databricks.com/blog/2018/09/18/simplify-market-basket-analysis-using-fp-growth-on-databricks.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <br/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-ads.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://databricks.com/wp-content/uploads/2018/09/recommend.png" alt="stock-data-analysis-streaming-ui" width="300" />
#     <br/>
#   </td>
#   <td valign="top" align="center">
#     <a href="$./References/Retail/dynamic-time-warping-mlflow-sales" target="_blank">Predict Sales Trends with MLflow and DTW<a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/dtw-mlflow-sales.zip" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://databricks.com/blog/2019/04/30/using-dynamic-time-warping-and-mlflow-to-detect-sales-trends.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-ads.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <br/><br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://upload.wikimedia.org/wikipedia/commons/6/69/Euclidean_vs_DTW.jpg" alt="stock-data-analysis-streaming-ui" width="300" />
#     <br/>
#   </td>
#   <td valign="top" align="center">
#     <a href="$./References/Retail/dynamic-time-warping-background" target="_blank">DTW Background</a><br/>
#     <a href="https://pages.databricks.com/rs/094-YMS-629/images/dtw-mlflow-sales.zip" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-notebook.png" width="80"/>
#     </a>
#     <a href="https://databricks.com/blog/2019/04/30/understanding-dynamic-time-warping.html" target="_blank">
#       <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-fmt-blog.png" width="80"/>
#     </a>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-vrt-ads.png" width=60/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-ml.png" width=40/>
#     <img src="https://pages.databricks.com/rs/094-YMS-629/images/tag-tech-sql.png" width=40/>
#     <br/>
#     <img class=" size-full wp-image-2358 aligncenter" src="https://pages.databricks.com/rs/094-YMS-629/images/dtw-animated.gif" width="300" />
#     <br/>
#   </td>
# </tr>
# </table>
